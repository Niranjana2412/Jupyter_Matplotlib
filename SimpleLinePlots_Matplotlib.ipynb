# %%
import matplotlib.pyplot as plt
import matplotlib as mtb
import numpy as np
plt.style.use('seaborn-whitegrid')

# %%
#To create a figure and an axis
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# '''
# In Matplotlib, the figure(an instance of class plt.Figure) can be thought of a single container which contains
# all the objects containing axes, graphics, texts and labels.
# '''

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0,10,100)
ax.plot(x, np.sin(x))

# %%
#for a pylab interface:
plt.plot(x, np.sin(x))

# %% [markdown]
# To create a single figure with multiple lines, call the plt.plot() function repeatedly

# %%
plt.plot(x, np.tan(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# The plt.plot() function takes additional arguments that can be used to specify these. To adjust the color, you can use the color keyword, which accepts a string argument representing virtually any imaginable color.

# %% [markdown]
# Specifying color by name:

# %%
plt.plot(x, np.sin(x-0), color = 'blue')

# %%
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name plt.plot(x, np.sin(x - 1), color='g')           
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk) 
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1 
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF) 
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %% [markdown]
# If no color is specified, Matplotlib will automatically cycle through a set of default colors for multiple lines.

# %% [markdown]
# To adjust the line style, use linestyle keyword!

# %%
plt.plot(x, x + 0, linestyle = 'solid')
plt.plot(x, x + 1, linestyle = 'dashed')
plt.plot(x, x + 2, linestyle = 'dashdot')
plt.plot(x, x + 3, linestyle = 'dotted')

# %% [markdown]
# This is the short-hand notation for that:

# %%
plt.plot(x, x + 4, linestyle='-')  # solid       
plt.plot(x, x + 5, linestyle='--') # dashed       
plt.plot(x, x + 6, linestyle='-.') # dashdot       
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# Combining color and linestyle into a single non-keyword argument:

# %%
plt.plot(x, x + 0, '-g')  # solid green       
plt.plot(x, x + 1, '--c') # dashed cyan       
plt.plot(x, x + 2, '-.k') # dashdot black       
plt.plot(x, x + 3, ':r');  # dotted red

# %%
plt.plot(x, np.sin(x))
plt.xlim(0, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# To display it in reverse

# %%
plt.plot(x, np.sin(x))
plt.xlim(10, 0)        
plt.ylim(1.2, -1.2)
# Out:
# (1.2, -1.2)

# %% [markdown]
# A useful related method is plt.axis() (note here the potential confusion between axEs with an e, and axIs with an i). The plt.axis() method allows you to set the x and y limits with a single call, by passing a list that specifies [xmin, xmax, ymin, ymax]

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])
# Out:
# [-1, 11, -1.5, 1.5]

# %% [markdown]
# To tighten the boundaries around the plot using plt.axis() method:

# %%
plt.plot(x, np.sin(x), color = 'g')
plt.axis('tight')
# Out:
# (-0.5, 10.5, -1.0993384025373631, 1.0996461858110391)

# %% [markdown]
# For equal aspect ratio:

# %%
plt.plot(x, np.cos(x), color = 'magenta')
plt.axis('equal')
# Out:
# (-0.5, 10.5, -1.0999445244849302, 1.0999973583088063)

# %% [markdown]
# To give a title to a plot and label the axes:

# %%
plt.plot(x, np.sin(x), color = 'orange')
plt.title('Sine Wave')
plt.xlabel('X')
plt.ylabel('sin(X)')
# Out:
# Text(0, 0.5, 'sin(X)')

# %% [markdown]
# When multiple lines are being shown within a single axes, it can be useful to create a plot legend that labels each line type. It is done via the plt.legend() method.

# %% [markdown]
# One way is to specify the label of each line using label keyword of the plot() function

# %%
plt.plot(x, np.sin(x), 'g', label = 'sin(x)')
plt.plot(x, np.cos(x), ':b', label = 'cos(x)')
plt.axis('equal')

plt.legend()

# %% [markdown]
#  plt.legend() function keeps track of the line style and color, and matches these with the correct label

# %% [markdown]
# # Matplotlib Gotchas

# %% [markdown]
# While most plt functions translate directly to ax methods (such as plt.plot() → ax.plot(), plt.legend() → ax.legend(), etc.), this is not the case for all commands. In particular, functions to set limits, labels, and titles are slightly modified. For transitioning between MATLAB-style functions and object-oriented methods, make the following changes:

# %% [markdown]
#  plt.xlabel() → ax.set_xlabel()
#
#  plt.ylabel() → ax.set_ylabel()
#
#  plt.xlim() → ax.set_xlim()
#
#  plt.ylim() → ax.set_ylim()
#
#  plt.title() → ax.set_title()

# %% [markdown]
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the ax.set() method to set all these properties at once

# %% [markdown]
# An example code:

# %%
ax = plt.axes()
ax.plot(x, np.sin(x), 'magenta')
ax.set(xlim = (0,11), ylim = (-1.5, 1.5), xlabel = 'X', ylabel = 'sin(X)', title = 'A simple plot')
# Out:
# [(-1.5, 1.5),
#  Text(0, 0.5, 'sin(X)'),
#  (0, 11),
#  Text(0.5, 0, 'X'),
#  Text(0.5, 1.0, 'A simple plot')]
